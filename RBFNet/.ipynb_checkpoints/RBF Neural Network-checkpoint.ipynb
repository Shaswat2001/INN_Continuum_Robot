# %%
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../Dataset/PCC/MLDataset_quat.csv")
data = data.drop('Unnamed: 0',axis=1)

# %%
X = data.iloc[:,0:7].values

# %%
k_mean = KMeans(n_clusters = 100)
k_mean.fit(X)

# %%
k_mean.cluster_centers_
# Out:
# array([[ 1.72124970e+02, -1.07819077e+02,  2.38696699e+02,
#          7.59820397e-01,  3.43595928e-01,  5.48229010e-01,
#          2.46935547e-19],
#        [ 2.62183769e+01, -1.51127811e+01,  3.37098451e+02,
#          9.95330387e-01,  4.46662201e-02,  7.74315282e-02,
#         -3.28941701e-19],
#        [ 3.22934878e+01,  1.73369854e+02,  2.71117040e+02,
#          8.36905669e-01, -5.35385527e-01,  9.98535881e-02,
#          1.23924465e-19],
#        [-1.14956563e+02, -9.92657668e+01,  2.88654804e+02,
#          8.83824676e-01,  3.04083851e-01, -3.52072275e-01,
#          3.84629818e-19],
#        [-1.09084149e+02,  9.38938929e+01,  2.95027533e+02,
#          8.97507099e-01, -2.85619036e-01, -3.31935931e-01,
#          1.85699335e-19],
#        [-5.55181133e+00, -1.72697588e+02,  2.66629115e+02,
#          8.37452173e-01,  5.42804243e-01, -1.74818754e-02,
#         -8.54990575e-20],
#        [ 1.02368739e+02,  9.05888013e+01,  2.99158794e+02,
# ...
